# %%
37800+390+850-2000+37800*0.06
# Out:
# 39308.0

# %%
37800+390+850-2000+34800*0.06
# Out:
# 39128.0

# %%
39128-1850
# Out:
# 37278

# %%
34800+280+2104.8+100+271+15+100-2000
# Out:
# 35670.8

# %%
39128-1850
# Out:
# 37278

# %%
39128-35670.8
# Out:
# 3457.199999999997

# %%
car_exp = 37800
file_exp = 390 + 5
trans_exp = 850
cash_on_deposit = 2000
tax = 34800 * 0.06
tax2 = 2104.8
license_plate = 371
True_Balance_due = car_exp + file_exp + trans_exp - cash_on_deposit + tax + license_plate
True_Balance_due2 = car_exp + file_exp + trans_exp - cash_on_deposit + tax2 + license_plate 
print(tax)
print(True_Balance_due)
print(True_Balance_due2-1850)
Fake_Balance_due = 35670.8
zelle = True_Balance_due - Fake_Balance_due
print(zelle)
# Out:
# 2088.0
# 39504.0
# 37670.8
# 3833.199999999997
